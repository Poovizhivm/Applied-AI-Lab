# %%
# !pip install mtcnn lz4
# Out:
# Requirement already satisfied: mtcnn in /usr/local/lib/python3.12/dist-packages (1.0.0)
# Requirement already satisfied: lz4 in /usr/local/lib/python3.12/dist-packages (4.4.5)
# Requirement already satisfied: joblib>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from mtcnn) (1.5.3)

# %%
from mtcnn import MTCNN
import cv2
from google.colab.patches import cv2_imshow

# %%
img = cv2.imread('face.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=391x261>

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
cv2_imshow(img_rgb)
# Out:
# <PIL.Image.Image image mode=RGB size=391x261>

# %%
from mtcnn import MTCNN
detector = MTCNN()

# %%
faces = detector.detect_faces(img_rgb)
print(faces)
# Out:
# [{'box': [272, 139, 26, 36], 'confidence': np.float64(0.9999976754188538), 'keypoints': {'nose': [np.int64(282), np.int64(161)], 'mouth_right': [np.int64(291), np.int64(165)], 'right_eye': [np.int64(289), np.int64(153)], 'left_eye': [np.int64(277), np.int64(154)], 'mouth_left': [np.int64(278), np.int64(166)]}}, {'box': [302, 38, 26, 36], 'confidence': np.float64(0.999930202960968), 'keypoints': {'nose': [np.int64(314), np.int64(59)], 'mouth_right': [np.int64(321), np.int64(63)], 'right_eye': [np.int64(320), np.int64(51)], 'left_eye': [np.int64(308), np.int64(53)], 'mouth_left': [np.int64(310), np.int64(65)]}}, {'box': [129, 30, 24, 32], 'confidence': np.float64(0.9999240040779114), 'keypoints': {'nose': [np.int64(142), np.int64(49)], 'mouth_right': [np.int64(148), np.int64(53)], 'right_eye': [np.int64(147), np.int64(42)], 'left_eye': [np.int64(136), np.int64(42)], 'mouth_left': [np.int64(136), np.int64(53)]}}, {'box': [87, 121, 27, 37], 'confidence': np.float64(0.9997515082359314), 'keypoints': {'nose': [np.int64(102), np.int64(142)], 'mouth_right': [np.int64(107), np.int64(147)], 'right_eye': [np.int64(107), np.int64(135)], 'left_eye': [np.int64(95), np.int64(135)], 'mouth_left': [np.int64(94), np.int64(147)]}}, {'box': [236, 38, 21, 31], 'confidence': np.float64(0.9997107982635498), 'keypoints': {'nose': [np.int64(248), np.int64(57)], 'mouth_right': [np.int64(253), np.int64(60)], 'right_eye': [np.int64(253), np.int64(49)], 'left_eye': [np.int64(242), np.int64(49)], 'mouth_left': [np.int64(241), np.int64(59)]}}, {'box': [57, 36, 24, 33], 'confidence': np.float64(0.999352753162384), 'keypoints': {'nose': [np.int64(69), np.int64(57)], 'mouth_right': [np.int64(74), np.int64(60)], 'right_eye': [np.int64(75), np.int64(49)], 'left_eye': [np.int64(63), np.int64(49)], 'mouth_left': [np.int64(62), np.int64(60)]}}, {'box': [183, 103, 27, 37], 'confidence': np.float64(0.9990543723106384), 'keypoints': {'nose': [np.int64(197), np.int64(126)], 'mouth_right': [np.int64(203), np.int64(130)], 'right_eye': [np.int64(203), np.int64(118)], 'left_eye': [np.int64(190), np.int64(118)], 'mouth_left': [np.int64(189), np.int64(130)]}}]

# %%
for face in faces:
    x, y, w, h = face['box']
    cv2.rectangle(img, (x, y), (x+w, y+h), (0, 255, 0), 2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=391x261>

# %%
import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('face.jpg')
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=391x261>

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=391x261>

# %%
import numpy as np
integral_img = cv2.integral(gray)
integral_display = cv2.normalize(integral_img, None, 0, 255, cv2.NORM_MINMAX)
integral_display = np.uint8(integral_display)
cv2_imshow(integral_display)
# Out:
# <PIL.Image.Image image mode=L size=392x262>

# %%
edges = cv2.Canny(gray, 100, 200)
cv2_imshow(edges)
# Out:
# <PIL.Image.Image image mode=L size=391x261>

# %%
face_cascade = cv2.CascadeClassifier(
    cv2.data.haarcascades + 'haarcascade_frontalface_default.xml'
)
faces = face_cascade.detectMultiScale(gray, 1.1, 5)
for (x, y, w, h) in faces:
    cv2.rectangle(img, (x, y), (x+w, y+h), (255, 0, 0), 2)
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=391x261>
